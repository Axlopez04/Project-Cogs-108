# %% [markdown]
# # COGS 108 - Project Proposal

# %% [markdown]
# # Names
#
# - Peyton Fisk
# - Ava Trachta
# - Kyra Allen
# - Alijah Lopez

# %% [markdown]
# # Research Question

# %% [markdown]
# Which diets lead to longer life spans in America?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# This section will present the background and context of your topic and question in a few paragraphs. Include a general introduction to your topic and then describe what information you currently know about the topic after doing your initial research. Include references to other projects who have asked similar questions or approached similar problems. Explain what others have learned in their projects.
#
# Find some relevant prior work, and reference those sources, summarizing what each did and what they learned. Even if you think you have a totally novel question, find the most similar prior work that you can and discuss how it relates to your project.
#
# References can be research publications, but they need not be. Blogs, GitHub repositories, company websites, etc., are all viable references if they are relevant to your project. It must be clear which information comes from which references. (2-3 paragraphs, including at least 2 references)
#
# Several factors influence an individual's lifespan, including genetics, environmental conditions, behavior, and diet. Genetics determines our susceptibility to certain diseases and influences our body’s ability to repair itself. Environmental factors like air quality, access to healthcare, and socioeconomic status also play a role in longevity. Behaviors such as physical activity, smoking, alcohol consumption, and stress management significantly impact health outcomes. Diet, however, is one of the most modifiable factors affecting lifespan. A balanced diet can prevent chronic diseases, reduce inflammation, and support overall health. The goal of our project is to investigate how specific dietary patterns contribute to a longer lifespan. We aim to identify which diets or nutrients may help reduce the risk of age-related diseases and promote longevity.
#
# A study by Caprara (2018) <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) analyzed how different diets reduce non-communicable diseases (NCDs). NCDs are diseases that do not transfer from person to person through infectious agents (heart disease, stroke, cancer, diabetes, and chronic lung disease). In the study, Caprara examined seven different dietary patterns to assess their potential in reducing the prevalence and impact of these conditions. The diets studied included the Mediterranean diet, known for its emphasis on healthy fats, fruits, and vegetables; the Japanese diet, which is rich in fish, rice, and plant-based foods; the vegetarian diet, which eliminates animal products; the new Nordic diet, which focuses on locally sourced, seasonal foods; the fast-mimicking diet, which simulates the effects of fasting while still providing essential nutrients; and the caloric restriction diet, which involves reducing calorie intake without malnutrition.These diets, common in Blue Zones where people live longer, share key features: high intake of plant-based foods, whole grains, unsaturated fats, and moderate protein, with a focus on omega-3s and antioxidants. They also limit red meat, processed foods, and sugars. Caprara also claimed that adopting a plant-based diet, alongside intermittent fasting and active living, can significantly reduce NCD risk and promote a longer, healthier life.
#
# A study by Willcox et al. (2007) <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) explored the link between caloric restriction (CR) and the logn life span of the Okinawan population, specifically those aged 65 and older. The research found that Okinawans have some of the longest life expectancies in the world, and their longevity can be attributed to mild, long-term caloric restriction. This population historically consumed a nutrient-dense, low-calorie diet, combined with high physical activity levels, which may have contributed to lower mortality from age-related diseases and extended survival. The study suggests that energy deficits in early life led to adaptations that promoted healthier aging and a longer lifespan.
#
#  **Use inline citation through HTML footnotes to specify which references support which statements**
#
# For example: After government genocide in the 20th century, real birds were replaced with surveillance drones designed to look just like birds. Use a minimum of 2 or 3 citations, but we prefer more. You need enough to fully explain and back up important facts.
#
# Note that if you click a footnote number in the paragraph above it will transport you to the proper entry in the footnotes list below.  And if you click the ^ in the footnote entry, it will return you to the place in the main text where the footnote is made.
#
# To understand the HTML here, `<a name="#..."> </a>` is a tag that allows you produce a named reference for a given location.  Markdown has the construciton `[text with hyperlink](#named reference)` that will produce a clickable link that transports you the named reference.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Caprara, G. (2018). Diet and longevity: The effects of traditional eating habits on human lifespan extension. Mediterranean Journal of Nutrition and Metabolism, 11(3), 261–294. https://doi.org/10.3233/mnm-180225
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Willcox, B. J., Willcox, D. C., Todoriki, H., Fujiyoshi, A., Yano, K., HE, Q., Curb, J. D., & Suzuki, M. (2007). Caloric Restriction, the Traditional Okinawan Diet, and Healthy Aging: The Diet of the World’s Longest-Lived People and Its Potential Impact on Morbidity and Life Span. Annals of the New York Academy of Sciences, 1114(1), 434–455. https://doi.org/10.1196/annals.1396.037

# %% [markdown]
# # Hypothesis

# %% [markdown]
# - We predict that diets similar to those found in Blue Zones, such as the Mediterranean and plant-based diets, will show a positive correlation with longer life expectancy in the United States, particularly in regions where these dietary patterns are more prevalent.
# - Why: Blue Zones have consistently shown high life expectancies, which are attributed to their residents' diets that are rich in plant-based foods, healthy fats, and antioxidants. Based on this, we hypothesize that areas in the U.S. that also adopt similar dietary patterns will have higher average life expectancies. We believe that the nutrients in these diets, such as omega-3 fatty acids and antioxidants, contribute to reduced inflammation, improved cardiovascular health, and a lower incidence of chronic diseases, all of which may lead to longer lifespans. Ultimately, demographics that eat these foods more often will most likely include areas of higher socioeconomic status to afford diverse and healthy food options.

# %% [markdown]
# # Data

# %% [markdown]
# 1. Explain what the **ideal** dataset you would want to answer this question. (This should include: What variables? How many observations? Who/what/how would these data be collected? How would these data be stored/organized?)
#
#  The ideal datasets we would want to answer this question would have detailed information about peoples’ dietary trends in different U.S. states. It would include variables such as the average lifespan on a state/county level, geographic information, frequency of consumption of different foods ( fruits and vegetables, meat, dairy, processed food, omega-3 rich foods, etc.), demographic information like age, gender, and income, and pre-existing health conditions such as heart-disease, diabetes, or obesity. This dataset would ideally have hundreds of thousands of observations to provide a strong sample that can be generalized to the U.S. population. This data would be collected continuously over a period of time so we could compare how different diets affect long-term health. The data would be collected by the CDC, the National Health and Nutrition Examination Survey, and the USDA and stored as CSV files. This dataset would let us compare diets in regions with high life expectancy to those in regions with low life expectancy, while controlling for factors like income, demographics, and health conditions.
# 2. Search for potential **real** datasets that could provide you with something useful for this project.  You do not have to find every piece of data you will use, but you do need to have demonstrated some idea that (a) this data is gettable and (b) that this data may be different from what your ideal is.
#
#  Some potential datasets we found to use for this project are Blue Zones, Worldwide Meat Consumption, Global Food Prices, Fruits and Vegetable Prices (in major US cities), Heart Disease Indicators, National Health and Nutrition Examination Survey, and Human Life Expectancy Around the World. With the Blue Zones and Human Life Expectancy Around the World datasets we can analyze the life expectancy across the U.S. and begin comparing regions with high vs. low life expectancy. We could use the Heart Disease Indicators dataset to see what effect fruit and vegetable consumption and pre-existing health conditions had on lifespan. The Global Food Prices and Fruits and Vegetable Prices datasets would let us extend our research to see what affect the cost of foods had on peoples’ consumption of them. The NHANES data has valuable information about diet, demographics, medical conditions, and mortality information that we can use in our project.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Acknowledge and address any ethics & privacy related issues of your question(s), proposed dataset(s), and/or analyses. Use the information provided in lecture to guide your group discussion and thinking. If you need further guidance, check out [Deon's Ethics Checklist](http://deon.drivendata.org/#data-science-ethics-checklist). In particular:
#
# - Are there any biases/privacy/terms of use issues with the data you propsed?
#
#  Sample Bias - looking at specific areas such as blue zones can have very specified demographic groups, including those who have access to specific foods, socioeconomic factors, and diversity of genetics.
#
#  Privacy issues - As with all data science projects, personal privacy is always a concern, however we can create anonymity and transparency for potential participants. In instances of using outside datasets, we will make sure the data were collected ethically and anonymously as well.
# - Are there potential biases in your dataset(s), in terms of who it composes, and how it was collected, that may be problematic in terms of it allowing for equitable analysis? (For example, does your data exclude particular populations, or is it likely to reflect particular human biases in a way that could be a problem?)
#
#  Potentially. If we do end up looking at blue zones, there is a chance that specific demographics will be looked at more than others, which would in turn bias to a particular diet due to culture and/or location. This could bias our findings towards a particular dietary pattern or health behavior associated with those regions, potentially overlooking other factors that contribute to longevity or well-being in different populations. To ensure a more equitable analysis, it would be crucial to account for these biases by expanding the dataset to include a broader variety of populations and carefully considering how factors like culture, geography, and access to resources impact the data.
# - How will you set out to detect these specific biases before, during, and after/when communicating your analysis?
#
#  Before Analysis: To detect biases before analysis, we will carefully select ethically produced/diverse datasets to ensure that diverse demographics and regions are represented.
#
#  During Analysis: While analyzing the data, we will use exploratory data analysis (EDA) to check for imbalances in key variables and perform bias testing to ensure no group is disproportionately affecting the results.
#
#  After Analysis: After completing the analysis, we will communicate the potential biases via a limitations section, discussing how they may have impacted the findings. By acknowledging these limitations, we’ll ensure the audience understands the scope and context of the results and provide recommendations for future research to address any gaps in representation.
# - Are there any other issues related to your topic area, data, and/or analyses that are potentially problematic in terms of data privacy and equitable impact?
#
#  Ethical Implications of Findings: If the analysis leads to conclusions that could have a disproportionate impact on certain communities—such as promoting specific diets or lifestyle habits based on the findings—there's a risk that recommendations may not be culturally appropriate, feasible, or accessible for all populations.
# - How will you handle issues you identified?
#
#  The biggest way to handle these potential issues is ultimately acknowledging these potential limitations.  We will also ensure our lifestyle recommendations promote accessibility for all communities, not just those with more resources or higher socioeconomic status.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# Read over the [COGS108 Team Policies](https://github.com/COGS108/Projects/blob/master/COGS108_TeamPolicies.md) individually. Then, include your group’s expectations of one another for successful completion of your COGS108 project below. Discuss and agree on what all of your expectations are. Discuss how your team will communicate throughout the quarter and consider how you will communicate respectfully should conflicts arise. By including each member’s name above and by adding their name to the submission, you are indicating that you have read the COGS108 Team Policies, accept your team’s expectations below, and have every intention to fulfill them. These expectations are for your team’s use and benefit — they won’t be graded for their details.
#
# * *Team Expectation 1*: Communication is key - engage in group discussions in zoom calls and in message group chat.
# * *Team Expectation 2*: Do your part - do not let your groupmates pull your weight.
# * *Team Expecation 3*: Do your best! Do not let your groupmates down.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# Specify your team's specific project timeline. An example timeline has been provided. Changes the dates, times, names, and details to fit your group's plan.
#
# If you think you will need any special resources or training outside what we have covered in COGS 108 to solve your problem, then your proposal should state these clearly. For example, if you have selected a problem that involves implementing multiple neural networks, please state this so we can make sure you know what you’re doing and so we can point you to resources you will need to implement your project. Note that you are not required to use outside methods.
#
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/7  |  5 PM | Look over project proposal and come up with ideas  | Discuss our hypothesis question and divvy up the work |
# | 2/17  |  5 PM |  Find datasets that will fit our research question | Choose datasets, dataclean and complete checkpoint 1 |
# | 3/3  | 5 PM  | Go over checkpoint 2 and prepare how we can tackle it  | EDA: complete checkpoint 2   |
# | 3/14  | 5 PM  | Get an idea of what part of the final project you want to work | Go through project proposal, and divvy up work   |
# | 3/19  | 5 PM  | Complete your part of the project | Compile our work, finish up details, and turn project in |
